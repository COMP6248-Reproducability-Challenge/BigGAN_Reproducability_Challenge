# %%
# !git clone https://github.com/VoiceBeer/BigGAN-PyTorch.git
# Out:
# Cloning into 'BigGAN-PyTorch'...
# remote: Enumerating objects: 30, done.
# remote: Counting objects: 100% (30/30), done.
# remote: Compressing objects: 100% (30/30), done.
# remote: Total 513 (delta 18), reused 0 (delta 0), pack-reused 483
# Receiving objects: 100% (513/513), 5.60 MiB | 38.99 MiB/s, done.
# Resolving deltas: 100% (348/348), done.

# %%
# 指定当前的工作文件夹
import os

# 此处为google drive中的文件路径,drive为之前指定的工作根目录，要加上
os.chdir("BigGAN-PyTorch")

# %%
ls
# Out:
# animal_hash.py                  inception_utils.py  sample.py
# BigGANdeep.py                   layers.py           scripts/
# BigGAN.py                       LICENSE             sync_batchnorm/
# calculate_inception_moments.py  logs/               TFHub/
# datasets.py                     losses.py           train_fns.py
# imgs/                           make_hdf5.py        train.py
# inception_tf13.py               README.md           utils.py

# %%
from os.path import exists
if not exists('ImageNet'):
    # !wget -O ImageNet.zip https://www.dropbox.com/s/mk74irpf2mfgelv/data.zip?dl=0
    # !unzip ImageNet.zip
# Out:
# --2019-05-17 13:35:11--  https://www.dropbox.com/s/mk74irpf2mfgelv/data.zip?dl=0
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.9.1, 2620:100:6031:1::a27d:5101
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.9.1|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/raw/mk74irpf2mfgelv/data.zip [following]
# --2019-05-17 13:35:11--  https://www.dropbox.com/s/raw/mk74irpf2mfgelv/data.zip
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uca90100177ec66fd9057541c7d0.dl.dropboxusercontent.com/cd/0/inline/AhA3EBuXNY4ohfN8UAKQuWS3gtRdY32aq0ZxcvRK58W_qdv-ZpYFAWoqgnE9fpVlR48TvLzqarWq7kNwDKfvpFPIx9RgCQjVrdWuwss9GO1ieg/file# [following]
# --2019-05-17 13:35:12--  https://uca90100177ec66fd9057541c7d0.dl.dropboxusercontent.com/cd/0/inline/AhA3EBuXNY4ohfN8UAKQuWS3gtRdY32aq0ZxcvRK58W_qdv-ZpYFAWoqgnE9fpVlR48TvLzqarWq7kNwDKfvpFPIx9RgCQjVrdWuwss9GO1ieg/file
# ...

# %%
# !sh scripts/utils/prepare_data.sh
# Out:
# {'dataset': 'I128', 'data_root': 'data', 'batch_size': 256, 'num_workers': 16, 'chunk_size': 500, 'compression': False}
# Using dataset root location data/ImageNet
# Data will not be augmented...
# Generating  Index file I128_imgs.npz...
# 100% 1/1 [00:00<00:00, 236.59it/s]
# Starting to load I128 into an HDF5 file with chunk size 500 and compression None...
#   0% 0/5 [00:00<?, ?it/s]Producing dataset of len 1087
# Image chunks chosen as (500, 3, 128, 128)
# Label chunks chosen as (500,)
# 100% 5/5 [00:01<00:00,  1.81it/s]
# {'dataset': 'I128_hdf5', 'data_root': 'data', 'batch_size': 64, 'parallel': False, 'augment': False, 'num_workers': 8, 'shuffle': False, 'seed': 0}
# Using dataset root location data/ILSVRC128.hdf5
# Downloading: "https://download.pytorch.org/models/inception_v3_google-1a9a5a14.pth" to /root/.cache/torch/checkpoints/inception_v3_google-1a9a5a14.pth
# 100% 108857766/108857766 [00:01<00:00, 92713011.68it/s]
# 100% 17/17 [00:04<00:00,  4.62it/s]
# ...

# %%
# !sh scripts/launch_BigGAN_bs256x8.sh
# Out:
# {'dataset': 'I128_hdf5', 'augment': False, 'num_workers': 4, 'pin_memory': True, 'shuffle': True, 'load_in_mem': True, 'use_multiepoch_sampler': True, 'model': 'BigGAN', 'G_param': 'SN', 'D_param': 'SN', 'G_ch': 96, 'D_ch': 96, 'G_depth': 1, 'D_depth': 1, 'D_wide': True, 'G_shared': True, 'shared_dim': 128, 'dim_z': 120, 'z_var': 1.0, 'hier': True, 'cross_replica': False, 'mybn': False, 'G_nl': 'inplace_relu', 'D_nl': 'inplace_relu', 'G_attn': '64', 'D_attn': '64', 'norm_style': 'bn', 'seed': 0, 'G_init': 'ortho', 'D_init': 'ortho', 'skip_init': False, 'G_lr': 0.0001, 'D_lr': 0.0004, 'G_B1': 0.0, 'D_B1': 0.0, 'G_B2': 0.999, 'D_B2': 0.999, 'batch_size': 20, 'G_batch_size': 0, 'num_G_accumulations': 8, 'num_D_steps': 1, 'num_D_accumulations': 8, 'split_D': False, 'num_epochs': 10, 'parallel': True, 'G_fp16': False, 'D_fp16': False, 'D_mixed_precision': False, 'G_mixed_precision': False, 'accumulate_stats': False, 'num_standing_accumulations': 16, 'G_eval_mode': True, 'save_every': 500,
# ...

# %%
# !sh scripts/Sample_BigGAN_bs256x8.sh
# Out:
# {'dataset': 'I128_hdf5', 'augment': False, 'num_workers': 2, 'pin_memory': True, 'shuffle': True, 'load_in_mem': False, 'use_multiepoch_sampler': True, 'model': 'BigGAN', 'G_param': 'SN', 'D_param': 'SN', 'G_ch': 96, 'D_ch': 96, 'G_depth': 1, 'D_depth': 1, 'D_wide': True, 'G_shared': True, 'shared_dim': 128, 'dim_z': 120, 'z_var': 1.0, 'hier': True, 'cross_replica': False, 'mybn': False, 'G_nl': 'inplace_relu', 'D_nl': 'inplace_relu', 'G_attn': '64', 'D_attn': '64', 'norm_style': 'bn', 'seed': 0, 'G_init': 'ortho', 'D_init': 'ortho', 'skip_init': True, 'G_lr': 0.0001, 'D_lr': 0.0004, 'G_B1': 0.0, 'D_B1': 0.0, 'G_B2': 0.999, 'D_B2': 0.999, 'batch_size': 20, 'G_batch_size': 512, 'num_G_accumulations': 8, 'num_D_steps': 1, 'num_D_accumulations': 8, 'split_D': False, 'num_epochs': 10, 'parallel': True, 'G_fp16': False, 'D_fp16': False, 'D_mixed_precision': False, 'G_mixed_precision': False, 'accumulate_stats': False, 'num_standing_accumulations': 16, 'G_eval_mode': True, 'save_every': 50
# ...
